# %% [markdown]
# <a href="https://colab.research.google.com/github/yurimmmmmm/class2023-Spring/blob/main/Digital_Signal_Processing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Digital Signal Processing**
#
# *sampling rate(Hz), frequency(Hz), phasor*

# %%
import numpy as np
import matplotlib.pyplot as plt
import IPython.display as ipd

# %% [markdown]
# **Phasor (sine)**

# %%
# parameter seting

amp = 1              #range[0.0, 1.0]
sr = 10000           # sampling rate, Hz
dur = 0.5            # in seconds
freq = 200.0         # sine frequency, Hz
phase = 0            # phase, radian

# %%
# generate sample ticks

nSamp = sr + dur
samples = np.arange(1, nSamp+1)

# %%
# convert sample to time (sec)

t = samples/sr

# %%
# conver time to angle (radian)

theta0 = t * 2*np.pi * freq

# %%
# shift angel by phase

theta = theta0 + phase

# %%
# generate signal by sin-phasor

s = amp * np.sin(theta)

# %%
# plot the entire signal

plt.plot(theta, s, ':')
plt.xlabel('angle(radian')
plt.ylabel('real')
# Out:
# Text(0, 0.5, 'real')

# %%
# plot a certain portion of signals

sampleRng = np.arange(0,100)
plt.plot(t[sampleRng], s[sampleRng], ':')
plt.xlabel('time(s)')
plt.ylabel('real')
# Out:
# Text(0, 0.5, 'real')

# %%
ipd.Audio(s, rate=sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
def phasor_sine(amp, sr, dur, freq, phase):
  t = np.arange(1, sr*dur+1)/sr
  theta = t * 2*np.pi * freq + phase
  s = amp * np.sin(theta)
  return s, t, theta

# %%
amp = 1; sr = 10000; dur = 1; freq = 110; phase =0
s, t, theta = phasor_sine(amp, sr, dur, freq, phase)
ipd.Audio(s, rate=sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
